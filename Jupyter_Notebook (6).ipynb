# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nataliya**
# <br>
# Data Scientist

# %% [markdown]
# *I am interested in data science because it is fascinating subject and I'm very curios about about all its aspects*

# %% [markdown]
# ### Assign variables to the numbers and add the numbers

# %%
one = 1
five = 5
print(one + five)
# Out:
# 6

# %% [markdown]
# **Flowers:**
#
# * Tulip
# * Rose
# * Daisy
#
#
#
# ![Space.png](attachment:40b8619a-f996-4b3b-b7f4-70715a9a769b.png)
#
# [www.google.co.uk](https://www.google.co.uk)
